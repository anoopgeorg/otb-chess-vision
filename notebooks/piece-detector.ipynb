# %%
from pathlib import Path
import cv2
import numpy as np
from matplotlib import pyplot as plt
from ultralytics import YOLO
import torch
# %matplotlib
# Out:
# Using matplotlib backend: <object object at 0x0000020216A2DD60>

# %%
# torch.cuda.is_available()
# torch.__version__
# Enable GPU for training
# if torch.cuda.is_available():
#     torch.cuda.set_device(0)
#     print("CUDA on GPU")
# else:
#     print("CUDA on CPU")
# Out:
# '2.1.0+cpu'

# %%
base = Path().absolute().parent
data_path_yaml = base/"data/raw/roboflow-chess-pieces/data.yaml"

# %%
model = YOLO('yolov8n.pt')

# %%
results = model.train(data=str(data_path_yaml),imgsz=416,epochs=100,batch=16,name='chess_piece_detector')
# Out:
# Ultralytics YOLOv8.0.200  Python-3.8.18 torch-2.1.0+cpu CPU (11th Gen Intel Core(TM) i5-11400H 2.70GHz)
# ...

# %%
model = YOLO('C:/Users/ANOOP/Desktop/Python/ai-porfolio/otb-chess-vision/notebooks/runs/detect/chess_piece_detector/weights/best.pt')
model.fuse()
# Out:
# Model summary (fused): 168 layers, 3008183 parameters, 0 gradients, 8.1 GFLOPs

# %%
img = cv2.imread("C:/Users/ANOOP/Desktop/Python/ai-porfolio/otb-chess-vision/src/ChessBoard/img_tests/1.jpg")

# %%
cv2.imshow(img,5000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\ANOOP\Desktop\Python\ai-porfolio\otb-chess-vision\notebooks\piece-detector.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ANOOP/Desktop/Python/ai-porfolio/otb-chess-vision/notebooks/piece-detector.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> cv2.imshow(img,5000)
#
# File c:\Users\ANOOP\anaconda3\envs\otb-chess-vision\lib\site-packages\ultralytics\utils\patches.py:55, in imshow(winname, mat)
#      47 def imshow(winname: str, mat: np.ndarray):
#      48     """
#      49     Displays an image in the specified window.
#      50
#    (...)
#      53         mat (np.ndarray): Image to be shown.
#      54     """
# ---> 55     _imshow(winname.encode('unicode_escape').decode(), mat)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'encode'

# %%
model.predict(img,line_thickness=1, conf=0.40, save_txt=True, save=True)
# Out:
# WARNING  'line_thickness' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'line_width' instead.
#
# 0: 416x416 2 black-bishops, 1 black-king, 2 black-knights, 8 black-pawns, 1 black-queen, 2 black-rooks, 2 white-bishops, 1 white-king, 2 white-knights, 8 white-pawns, 1 white-queen, 2 white-rooks, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 416)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'bishop', 1: 'black-bishop', 2: 'black-king', 3: 'black-knight', 4: 'black-pawn', 5: 'black-queen', 6: 'black-rook', 7: 'white-bishop', 8: 'white-king', 9: 'white-knight', 10: 'white-pawn', 11: 'white-queen', 12: 'white-rook'}
#  orig_img: array([[[195, 197, 197],
#          [190, 192, 192],
# ...

# %%
img = cv2.imread("C:/Users/ANOOP/Desktop/Python/ai-porfolio/otb-chess-vision/src/ChessBoard/img_tests/test_pieces.jpg")
model.predict(img,line_thickness=1, conf=0.40, save_txt=True, save=True)
# Out:
# WARNING  'line_thickness' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'line_width' instead.
#
# 0: 320x416 1 black-bishop, 3 black-rooks, 2 white-rooks, 315.5ms
# Speed: 71.9ms preprocess, 315.5ms inference, 32.0ms postprocess per image at shape (1, 3, 320, 416)
# Results saved to runs\detect\predict4
# 1 label saved to runs\detect\predict4\labels
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'bishop', 1: 'black-bishop', 2: 'black-king', 3: 'black-knight', 4: 'black-pawn', 5: 'black-queen', 6: 'black-rook', 7: 'white-bishop', 8: 'white-king', 9: 'white-knight', 10: 'white-pawn', 11: 'white-queen', 12: 'white-rook'}
#  orig_img: array([[[153, 175, 180],
#          [152, 174, 179],
#          [152, 174, 179],
#          ...,
#          [145, 158, 156],
#          [153, 166, 164],
#          [153, 166, 164]],
#
# ...
